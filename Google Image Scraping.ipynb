# %% [markdown]
# Google Image Scraping
#
# Data Collection Phase: In this section, you need to scrape images from Google, flipkart, Amazon.com. The clothing categories used for scraping will be:
#
# Sarees (women)
# Trousers (men)
# Jeans (men)

# %%
#import all the required libraries
import pandas as pd
import selenium
from selenium import webdriver
import time
#Importing requests
import requests
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
#Scraping Sarees images from Google

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r"C:\Users\Pooja.Mishra\Downloads\chromedriver_win32\chromedriver.exe") 
time.sleep(3)

# %%
# Opening the google images
url = "https://images.google.com/"
driver.get(url)

# %%
search_bar = driver.find_element_by_xpath('//*[@id="sbtc"]/div/div[2]/input')    # Finding the search bar using it's xpath
search_bar.send_keys("Sarees (women)")       
search_button = driver.find_element_by_xpath('//*[@id="sbtc"]/button')    
search_button.click()        # Clicking the search button

# %%
time.sleep(3)
start=0
end=4

img_urls = []
img_data = []
count=0
    
for page in range(0,3):
    images = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')
    for image in images:
        source= image.get_attribute('src')
        img_urls.append(source)
        count = len(img_urls)
    if count<=200:
        time.sleep(5)
        next_page=driver.find_element_by_xpath('//input[@class="mye4qd"]')
        next_page.click()
        time.sleep(5)

# %%
print (len(img_urls))
# Out:
# 1200

# %%
img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
for i in range(len(img_urls)):
    if i >= 200:
        break
    print("Downloading {0} of {1} images" .format(i, 200))
    response= requests.get(img_urls[i])
    file = open(r"C:\DS\images\images"+str(i)+".jpg", "wb")
    file.write(response.content)

# %% [markdown]
# #Scraping Trousers images from Google

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r"C:\Users\Pooja.Mishra\Downloads\chromedriver_win32\chromedriver.exe") 
time.sleep(3)

# %%
# Opening the google images
url2 = "https://images.google.com/"
driver.get(url2)

# %%
search_bar = driver.find_element_by_xpath('//*[@id="sbtc"]/div/div[2]/input')    # Finding the search bar using it's xpath
search_bar.send_keys("Trousers (men)")       
search_button = driver.find_element_by_xpath('//*[@id="sbtc"]/button')    
search_button.click()        # Clicking the search button

# %%
time.sleep(3)
start=0
end=4

img_urls2 = []
img_data2 = []
count=0
    
for page in range(0,4):
    images2 = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')
    for image1 in images2:
        source= image1.get_attribute('src')
        img_urls2.append(source)
        count = len(img_urls2)
    if count<=200:
        time.sleep(3)
        next_page2=driver.find_element_by_xpath('//input[@class="mye4qd"]')
        next_page2.click()
        time.sleep(3)

# %%
print (len(img_urls2))
# Out:
# 1600

# %%
img_urls2 = []
img_data2 = []
for image1 in images2:
    source= image1.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls2.append(source)
for j in range(len(img_urls2)):
    if j >= 200:
        break
    print("Downloading {0} of {1} images" .format(j, 200))
    response= requests.get(img_urls2[j])
    file = open(r"C:\DS\images\Trousers\Trousers"+str(j)+".jpg", "wb")
    file.write(response.content)

# %% [markdown]
# #Scraping Jeans images from Google

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r"C:\Users\Pooja.Mishra\Downloads\chromedriver_win32\chromedriver.exe") 
time.sleep(3)

# %%
# Opening the google images
url2 = "https://images.google.com/"
driver.get(url2)

# %%
search_bar = driver.find_element_by_xpath('//*[@id="sbtc"]/div/div[2]/input')    # Finding the search bar using it's xpath
search_bar.send_keys("Jeans (men)")       
search_button = driver.find_element_by_xpath('//*[@id="sbtc"]/button')    
search_button.click()        # Clicking the search button

# %%
time.sleep(3)
start=0
end=4

img_urls3 = []
img_data3 = []
count=0
    
for page in range(0,4):
    images3 = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')
    for image2 in images3:
        source= image2.get_attribute('src')
        img_urls3.append(source)
        count = len(img_urls3)
    if count<=200:
        time.sleep(3)
        next_page3=driver.find_element_by_xpath('//input[@class="mye4qd"]')
        next_page3.click()
        time.sleep(3)

# %%
img_urls3 = []
img_data3 = []
for image2 in images3:
    source= image2.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls3.append(source)
for k in range(len(img_urls3)):
    if k >= 200:
        break
    print("Downloading {0} of {1} images" .format(k, 200))
    response= requests.get(img_urls3[k])
    file = open(r"C:\DS\images\Jeans\Jeans"+str(k)+".jpg", "wb")
    file.write(response.content)

# %% [markdown]
# Note: Due to IP lock from E-com portals Amazon; scraping all images from Google. Max Retries SSL Error.
